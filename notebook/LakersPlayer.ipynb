# %%
import pandas as pd

# %%
#Reading csv
player_df = pd.read_csv('../static/Resources/teamsplayer.csv', encoding="ISO-8859-1")
player_df.head()
# Out:
#    Rk            Player  Age   G  GS    MP    FG   FGA    FG%   3P  ...  \
# 0   1      LeBron James   38  55  54  35.5  11.1  22.2  0.500  2.2  ...
# 1   2     Anthony Davis   29  56  54  34.0   9.7  17.2  0.563  0.3  ...
# 2   3  D'Angelo Russell   26  17  17  30.9   6.3  13.0  0.484  2.7  ...
# 3   4  Dennis Schr̦der   29  66  50  30.1   4.1   9.8  0.415  1.1  ...
# 4   5     Austin Reaves   24  64  22  28.8   4.0   7.7  0.529  1.3  ...
#
#      FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.768  1.2  7.1   8.3  6.8  0.9  0.6  3.2  1.6  28.9
# 1  0.784  3.5  9.1  12.5  2.6  1.1  2.0  2.2  2.6  25.9
# 2  0.735  0.4  2.5   2.9  6.1  0.6  0.5  2.3  1.4  17.4
# 3  0.857  0.3  2.2   2.5  4.5  0.8  0.2  1.7  2.2  12.6
# 4  0.864  0.5  2.5   3.0  3.4  0.5  0.3  1.5  1.7  13.0
#
# [5 rows x 28 columns]

# %%
player_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      24 non-null     int64
#  1   Player  24 non-null     object
#  2   Age     24 non-null     int64
#  3   G       24 non-null     int64
#  4   GS      24 non-null     int64
#  5   MP      24 non-null     float64
#  6   FG      24 non-null     float64
#  7   FGA     24 non-null     float64
#  8   FG%     24 non-null     float64
#  9   3P      24 non-null     float64
#  10  3PA     24 non-null     float64
#  11  3P%     24 non-null     float64
#  12  2P      24 non-null     float64
#  13  2PA     24 non-null     float64
#  14  2P%     24 non-null     float64
#  15  eFG%    24 non-null     float64
#  16  FT      24 non-null     float64
#  17  FTA     24 non-null     float64
#  18  FT%     24 non-null     float64
#  19  ORB     24 non-null     float64
#  20  DRB     24 non-null     float64
# ...

# %%
player_df.columns
# Out:
# Index(['Rk', 'Player', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA',
#        '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB',
#        'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
player_df = player_df.drop(columns = ['G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA',
                                      '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TOV', 'PF'
                                     ])
player_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 player_df = player_df.drop(columns = ['G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA',
#       2                                       '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TOV', 'PF'
#       3                                      ])
#       4 player_df.head()
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
player_df = player_df.fillna(0)
player_df.head()
# Out:
#    Rk            Player  Age   TRB  AST  STL  BLK   PTS
# 0   1      LeBron James   38   8.3  6.8  0.9  0.6  28.9
# 1   2     Anthony Davis   29  12.5  2.6  1.1  2.0  25.9
# 2   3  D'Angelo Russell   26   2.9  6.1  0.6  0.5  17.4
# 3   4  Dennis Schr̦der   29   2.5  4.5  0.8  0.2  12.6
# 4   5     Austin Reaves   24   3.0  3.4  0.5  0.3  13.0

# %%
output=player_df.to_csv('../static/Resources/teamsplayer.csv', index=False)
output
